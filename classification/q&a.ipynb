# %%
from transformers import pipeline

qa = pipeline("question-answering")

context = """
Artificial intelligence is a field of computer science focused on creating
machines that can perform tasks requiring human intelligence.
"""

result = qa(
    question="What is artificial intelligence?",
    context=context,
    temperature=0.9
)

print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# {'score': 0.27355825901031494, 'start': 28, 'end': 55, 'answer': 'a field of computer science'}
