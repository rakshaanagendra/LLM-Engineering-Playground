# %%
from transformers import pipeline

#ner = pipeline("ner",aggregation_strategy="simple")
ner = pipeline("ner")

result = ner("Elon Musk founded SpaceX in the United States")

print(result)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity': 'I-PER', 'score': np.float32(0.99947876), 'index': 1, 'word': 'El', 'start': 0, 'end': 2}, {'entity': 'I-PER', 'score': np.float32(0.9989766), 'index': 2, 'word': '##on', 'start': 2, 'end': 4}, {'entity': 'I-PER', 'score': np.float32(0.9991248), 'index': 3, 'word': 'Mu', 'start': 5, 'end': 7}, {'entity': 'I-PER', 'score': np.float32(0.9959675), 'index': 4, 'word': '##sk', 'start': 7, 'end': 9}, {'entity': 'I-ORG', 'score': np.float32(0.9982256), 'index': 6, 'word': 'Space', 'start': 18, 'end': 23}, {'entity': 'I-ORG', 'score': np.float32(0.99768984), 'index': 7, 'word': '##X', 'start': 23, 'end': 24}, {'entity': 'I-LOC', 'score': np.float32(0.99960464), 'index': 10, 'word': 'United', 'start': 32, 'end': 38}, {'entity': 'I-LOC', 'score': np.float32(0.99958426), 'index': 11, 'word': 'States', 'start': 39, 'end': 45}]
