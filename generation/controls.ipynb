# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "gpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

input_text = "I love"

inputs = tokenizer(input_text, return_tensors="pt")

output = model.generate(
    **inputs,
    max_length=20
)

print(tokenizer.decode(output[0]))
# Out:
# Loading weights: 100%|██████████| 148/148 [00:00<00:00, 5596.29it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I love the way you're doing it. I love the way you're doing it. I love

# %%
output = model.generate(
    **inputs,
    max_length=20,
    temperature=1.5,
    do_sample=True
)

print(tokenizer.decode(output[0]))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I love my job when I spend time playing around with my tools and finding the next magic item.

# %%
output = model.generate(
    **inputs,
    max_length=20,
    temperature=0.2,
    do_sample=True
)
print(tokenizer.decode(output[0]))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I love the way you're so kind and caring. I love how you're so kind and caring

# %%
output = model.generate(
    **inputs,
    max_length=20,
    do_sample=True,
    top_k=5
)
print(tokenizer.decode(output[0]))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I love you all so much!" She laughed as she hugged him, her face still warm and happy

# %%
output = model.generate(
    **inputs,
    max_length=70,
    do_sample=True,
    temperature=0.7,
    repetition_penalty=1.5,
    no_repeat_ngram_size=2,
    early_stopping=True,
    num_beams=5,
    top_p=0.9
)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# I love you."
#
# "Thank you," she said. "It's nice to see you again." She turned to look at him, but he didn't respond. He stared at her for a long moment, then turned back to her and took a deep breath. Then he looked back at his wife, who was sitting on the edge of
